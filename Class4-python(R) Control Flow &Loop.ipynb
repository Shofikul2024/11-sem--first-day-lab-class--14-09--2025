# %%
'''    

Code 1: গ্রেড সিস্টেম (Grade System)
marks = 66
if marks >= 80 and marks <= 100:
    print("A+")

elif marks >= 70 and marks < 80:
    print("A")

elif marks >= 60 and marks < 70:
    print("A-")

elif marks >= 50 and marks < 60:
    print("B")

elif marks >= 40 and marks < 50:
    print("C")

elif marks >= 33 and marks < 40:
    print("D")

else:
    print("F")


বাংলা ব্যাখ্যা:
এখানে একটি ছাত্রের নম্বর marks এর উপর ভিত্তি করে গ্রেড নির্ধারণ করা হচ্ছে। যদি নম্বর ৮০–১০০ এর মধ্যে হয় তবে A+, ৭০–৭৯ হলে A, ৬০–৬৯ হলে A-, ইত্যাদি। ৩৩ এর কম হলে F প্রিন্ট হবে।

English Explanation:
This code checks a student's marks and prints their grade. If the marks are between 80–100, it prints A+. If between 70–79, it prints A, 60–69 → A-, and so on. If marks are below 33, it prints F.

🔹 Code 2: বয়স ও পারমিশন চেক (Age & Permission Check)
age = 30
permission = False

if age >= 20:
    if permission == True:
        print("You can join with us")
    else:
        print("You can't join with us")
else:
    print("You are under aged")


বাংলা ব্যাখ্যা:
এখানে প্রথমে বয়স দেখা হচ্ছে। যদি বয়স ২০ বা তার বেশি হয় এবং permission সত্যি (True) হয়, তবে সে যোগ দিতে পারবে। যদি বয়স ঠিক থাকে কিন্তু অনুমতি না থাকে, তবে যোগ দিতে পারবে না। আর বয়স ২০ এর কম হলে "under aged" দেখাবে।

English Explanation:
This code checks if a person is 20 or older and has permission. If both conditions are true, they can join. If the age is enough but permission is False, they cannot join. If the age is below 20, it prints "You are under aged".

🔹 Code 3: for লুপ (For Loop)
girls = ["Katrina", "Carina", "Jarina", "Sakhina"]
for gf in girls:
    print(gf)


বাংলা ব্যাখ্যা:
এখানে for loop ব্যবহার করে লিস্টের প্রতিটি নাম একে একে প্রিন্ট করা হচ্ছে।

English Explanation:
Here, a for loop is used to print each name from the list one by one.

🔹 Code 4: while লুপ (While Loop)
girls = ["Katrina", "Carina", "Jarina", "Sakhina"]
chokkor = 0
while chokkor < len(girls):
    print(girls[chokkor])
    chokkor = chokkor + 1


বাংলা ব্যাখ্যা:
while loop ব্যবহার করে লিস্টের নামগুলো একে একে প্রিন্ট করা হচ্ছে। এখানে কাউন্টার chokkor প্রতি ধাপে ১ করে বাড়ছে।

English Explanation:
Using a while loop, each name from the list is printed. The counter chokkor increases by 1 each time until it reaches the list length.

🔹 Code 5: break স্টেটমেন্ট (Break Statement)
girls = ["Katrina", "Carina", "Jarina", "Sakhina"]
for gf in girls:
    if gf == "Jarina":
        break
    print(gf)


বাংলা ব্যাখ্যা:
যখন লুপে Jarina পাওয়া যাবে তখন লুপ বন্ধ হয়ে যাবে (break)। তাই এর পরে আর কিছু প্রিন্ট হবে না।

English Explanation:
When the loop finds "Jarina", it breaks and stops execution. So, names after "Jarina" are not printed.

🔹 Code 6: continue স্টেটমেন্ট (Continue Statement)
girls = ["Katrina", "Carina", "Jarina", "Sakhina"]
for gf in girls:
    if gf == "Carina":
        continue
    print(gf)


বাংলা ব্যাখ্যা:
যখন "Carina" পাওয়া যাবে তখন সেটা বাদ দিয়ে লুপ চালিয়ে যাবে। তাই "Carina" প্রিন্ট হবে না।

English Explanation:
When "Carina" is found, the loop skips it and continues. So, "Carina" is not printed.

🔹 Code 7: লজিক্যাল অপারেটর (Logical Operators)
age = 19
permission = True

if age >= 18 and permission == True:
    print("Welcome")


বাংলা: উভয় শর্ত (বয়স ≥১৮ এবং permission=True) পূরণ হলে Welcome প্রিন্ট হবে।
English: Prints Welcome only if both conditions are true.

age = 10
permission = True

if age >= 18 or permission == True:
    print("Welcome")


বাংলা: অন্তত একটি শর্ত সত্যি হলে Welcome প্রিন্ট হবে। এখানে বয়স ছোট হলেও permission=True, তাই Welcome হবে।
English: Prints Welcome if at least one condition is true. Here, permission is True, so it prints.

age = 10
permission = True

if not age > 18:
    print("Not Welcome")


বাংলা: যদি বয়স ১৮ এর বেশি না হয় (মানে ≤১৮), তবে Not Welcome প্রিন্ট হবে।
English: Prints Not Welcome if age is not greater than 18.

🔹 Code 8: Nested Loop (নেস্টেড লুপ)
girls = ["Katrina", "Carina", "Jarina"] 
girls_papa = ["KatrinaBap", "CarinaBap", "JarinaBap", "SakhinaBap"] 

for gf in girls:
    print(gf)
    for papa in girls_papa:
        print(papa)


বাংলা ব্যাখ্যা:
প্রথমে একটি girl প্রিন্ট হবে, তারপর তার সাথে লিস্টের সব papa প্রিন্ট হবে। এভাবে প্রতিটি মেয়ের জন্য সব বাবার নাম প্রিন্ট হবে।

English Explanation:
First, one girl is printed, then all papa names are printed for that girl. This repeats for each girl.

🔹 Code 9: হ্যালো প্রিন্ট (Hello Print)
print('hello')


বাংলা ব্যাখ্যা:
এটি শুধু hello প্রিন্ট করে।

English Explanation:
This simply prints hello.

'''
# Out:
# '    \n\nCode 1: গ্রেড সিস্টেম (Grade System)\nmarks = 66\nif marks >= 80 and marks <= 100:\n    print("A+")\n\nelif marks >= 70 and marks < 80:\n    print("A")\n\nelif marks >= 60 and marks < 70:\n    print("A-")\n\nelif marks >= 50 and marks < 60:\n    print("B")\n\nelif marks >= 40 and marks < 50:\n    print("C")\n\nelif marks >= 33 and marks < 40:\n    print("D")\n\nelse:\n    print("F")\n\n\nবাংলা ব্যাখ্যা:\nএখানে একটি ছাত্রের নম্বর marks এর উপর ভিত্তি করে গ্রেড নির্ধারণ করা হচ্ছে। যদি নম্বর ৮০–১০০ এর মধ্যে হয় তবে A+, ৭০–৭৯ হলে A, ৬০–৬৯ হলে A-, ইত্যাদি। ৩৩ এর কম হলে F প্রিন্ট হবে।\n\nEnglish Explanation:\nThis code checks a student\'s marks and prints their grade. If the marks are between 80–100, it prints A+. If between 70–79, it prints A, 60–69 → A-, and so on. If marks are below 33, it prints F.\n\n🔹 Code 2: বয়স ও পারমিশন চেক (Age & Permission Check)\nage = 30\npermission = False\n\nif age >= 20:\n    if permission == True:\n        print("You can join with us")\n    else:\n 
# ...

# %%
# Code 1: গ্রেড সিস্টেম (Grade System)

marks=66
if marks >=80 and marks<=100:
    print("A+")
elif marks>=70 and marks<80 :
    print("A")
elif marks>=60 and marks <70 :
    print("A-")
elif marks >=50 and marks < 60:
    print("B")
elif marks >=40 and marks < 50:  
    print("C")
elif marks >=33 and marks < 40:
    print("D")
else:  
    print("F")
# Out:
# A-
